# %%
numbers = [10, 20, 30, 40, 50]
# Traverse List
for num in numbers:
  print(numbers)
# Update List
numbers[2] = 35
print("Updated List:", numbers)
# Basic Operations
numbers.append(60)
numbers.remove(20)
print(numbers)
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# Updated List: [10, 20, 35, 40, 50]
# [10, 35, 40, 50, 60]
