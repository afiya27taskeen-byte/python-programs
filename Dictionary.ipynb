# %%
my_dict={}
my_dict1=dict()
print("The Dictionary is : ",my_dict)
print("The Dictionary is : ",my_dict1)
student={"Name":"Afiya","Age":18,"Regno.":562,"Branch":"CSE"}
print(student)
student1 = dict(Name="Afiya",Age=18,Regno="562")
print(student1)
# Out:
# The Dictionary is :  {}
# The Dictionary is :  {}
# {'Name': 'Afiya', 'Age': 18, 'Regno.': 562, 'Branch': 'CSE'}
# {'Name': 'Afiya', 'Age': 18, 'Regno': '562'}
