# %%
numbers = [10,20,30,40]
print("Original list:",numbers)
numbers.append(50)
print("After append numbers:",numbers)
numbers.insert(2,25)
print("After insert numbers:",numbers)
numbers.remove(30)
print("After remove numbers:",numbers)
print("lenghth list:",len(numbers))
print("List elements:")
for item in numbers:
    print(item)
# Out:
# Original list: [10, 20, 30, 40]
# After append numbers: [10, 20, 30, 40, 50]
# After insert numbers: [10, 20, 25, 30, 40, 50]
# After remove numbers: [10, 20, 25, 40, 50]
# lenghth list: 5
# List elements:
# 10
# 20
# 25
# 40
# 50
