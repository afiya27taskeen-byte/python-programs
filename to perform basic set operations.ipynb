# %%
set1 ={10,20,30,40}
set2 ={30,40,50,60}
print("union:", set1.union(set2))
print("Intersection:", set1.intersection(set2))
print("Difference:", set1.difference(set2))
set1.add(70)
print("updated set:",set1)
# Out:
# union: {40, 10, 50, 20, 60, 30}
# Intersection: {40, 30}
# Difference: {10, 20}
# updated set: {70, 40, 10, 20, 30}
