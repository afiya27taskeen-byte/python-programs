# %%
list1=[1,2,3,4,5,6]
list2=[7,8,9]
print("Sum of first list items:",sum(list1))
print("Sum of second list items:",sum(list2))
print("Sum of two lists items:",sum(list1+list2))
# Out:
# Sum of first list items: 21
# Sum of second list items: 24
# Sum of two lists items: 45
