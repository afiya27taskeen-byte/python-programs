# %%
student = {
"name": "Alice",
"roll_no": 101,
"course": "Python"
}
print(student["name"])
for key, value in student.items():
  print(key , value);
# Out:
# Alice
# name Alice
# roll_no 101
# course Python
