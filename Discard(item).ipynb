# %%
months={"jan","feb","Mar","apr"}
print("\n printing the original ser..")
print(months)
months.discard("apr")
print("\nPrinting the modified set")
print(months)
months.discard("May")
print("\nPrinting the modified set")
print(months)
# Out:
#  printing the original ser..
# {'Mar', 'feb', 'apr', 'jan'}
#
# Printing the modified set
# {'Mar', 'feb', 'jan'}
#
# Printing the modified set
# {'Mar', 'feb', 'jan'}
