# %%
student = {"Name":"Afiya","Age":22,"Regno.":562,"Branch":"CSE"}
print("Name : ",student["Name"])
print("Age : ",student["Age"])
print("Regno. : ",student["Regno."])
print("Branch : ",student["Branch"])
# Out:
# Name :  Afiya
# Age :  22
# Regno. :  562
# Branch :  CSE
