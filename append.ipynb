# %%
my_list=[1,2,3]
another_list=[4,5,6]
my_list.append(8)
print(my_list)
my_list.append(another_list)
print(my_list)
my_list.append((7,8))
print(my_list)
my_list.append(("abc"))
print(my_list)
# Out:
# [1, 2, 3, 8]
# [1, 2, 3, 8, [4, 5, 6]]
# [1, 2, 3, 8, [4, 5, 6], (7, 8)]
# [1, 2, 3, 8, [4, 5, 6], (7, 8), 'abc']
