# %%
numbers=[10,20,30,20,40,10,50]
unique_numbers= list(set(numbers))
print("original list")
print(numbers)
print("unique list")
print(unique_numbers)
# Out:
# original list
# [10, 20, 30, 20, 40, 10, 50]
# unique list
# [40, 10, 50, 20, 30]
